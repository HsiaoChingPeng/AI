# %%
#encoding=utf-8
import jieba

jieba.set_dictionary('dict.txt.big.txt')  
jieba.load_userdict('user_dict.txt')

sentence = "彭筱晴來到國立臺中教育大學就讀數位系110級"

breakword = jieba.cut(sentence, cut_all=False)
print("預設模式:" + '|' . join(breakword))

breakword = jieba.cut(sentence, cut_all=True)
print("全文模式:" + '|' . join(breakword))

breakword = jieba.cut_for_search(sentence)
print("搜尋引擎:" + '|' . join(breakword))
# Out:
# Building prefix dict from C:\Users\User\AI\1023斷詞與文字雲\dict.txt.big.txt ...
# Loading model from cache C:\Users\User\AppData\Local\Temp\jieba.u578cb2a7f0dd4121fe75b633ccdb3db2.cache
# Loading model cost 1.354 seconds.
# Prefix dict has been built succesfully.
# 預設模式:彭筱晴|來到|國立臺中教育大學|就讀|數位系|110級
# 全文模式:彭筱晴|來到|國立|國立臺中教育大學|臺中|教育|大學|就讀|讀數|數位|數位系|110|級
# 搜尋引擎:彭筱晴|來到|國立|臺中|教育|大學|國立臺中教育大學|就讀|數位|數位系|110級
